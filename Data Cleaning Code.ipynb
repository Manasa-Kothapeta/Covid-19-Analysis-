# %% [markdown]
# # Importing all Libraries

# %%
import os 
import numpy as np 
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns
from math import sqrt
from datetime import datetime

# %matplotlib inline

# %% [markdown]
# # Importing dataset

# %%
raw_data_country_wise = pd.read_csv('C:\\Users\\Manasa\\OneDrive\\Documents\\covid-19\\country_wise_latest.csv')

print("The Shape of confirmed is: ", raw_data_country_wise)


raw_data_country_wise.head()
# Out:
# The Shape of confirmed is:           Country/Region  Confirmed  Deaths  Recovered  Active  New cases  \
# 0           Afghanistan      36263    1269      25198    9796        106
# 1               Albania       4880     144       2745    1991        117
# 2               Algeria      27973    1163      18837    7973        616
# 3               Andorra        907      52        803      52         10
# 4                Angola        950      41        242     667         18
# ..                  ...        ...     ...        ...     ...        ...
# 182  West Bank and Gaza      10621      78       3752    6791        152
# 183      Western Sahara         10       1          8       1          0
# 184               Yemen       1691     483        833     375         10
# 185              Zambia       4552     140       2815    1597         71
# 186            Zimbabwe       2704      36        542    2126        192
#
# ...

# %% [markdown]
# # Un-Pivoting the data

# %%
raw_data_country_wise2 = pd.melt(raw_data_country_wise, id_vars=['Country/Region', 'Confirmed', 'Deaths', 'Recovered', 'Active', 'Recovery Rate', 'Fatality Rate'])
print("The Shape of Confirmed is: ", raw_data_country_wise2)
raw_data_country_wise2.head()
# Out:
# The Shape of Confirmed is:            Country/Region  Confirmed  Deaths  Recovered  Active  Recovery Rate  \
# 0            Afghanistan      36263    1269      25198    9796           3.50
# 1                Albania       4880     144       2745    1991           2.95
# 2                Algeria      27973    1163      18837    7973           4.16
# 3                Andorra        907      52        803      52           5.73
# 4                 Angola        950      41        242     667           4.32
# ...                  ...        ...     ...        ...     ...            ...
# 1491  West Bank and Gaza      10621      78       3752    6791           0.73
# 1492      Western Sahara         10       1          8       1          10.00
# 1493               Yemen       1691     483        833     375          28.56
# 1494              Zambia       4552     140       2815    1597           3.08
# 1495            Zimbabwe       2704      36        542    2126           1.33
#
# ...

# %% [markdown]
# # Deleting Unnecessary Columns

# %%
columns_to_delete = ['variable', 'value']  # Specifying the columns want to delete

# Dropping the columns
raw_data_country_wise2.drop(columns=columns_to_delete, inplace=True)
raw_data_country_wise2.head()
# Out:
#   Country/Region  Confirmed  Deaths  Recovered  Active  Recovery Rate  \
# 0    Afghanistan      36263    1269      25198    9796           3.50
# 1        Albania       4880     144       2745    1991           2.95
# 2        Algeria      27973    1163      18837    7973           4.16
# 3        Andorra        907      52        803      52           5.73
# 4         Angola        950      41        242     667           4.32
#
#    Fatality Rate
# 0           5.04
# 1           5.25
# 2           6.17
# 3           6.48
# 4          16.94

# %% [markdown]
# # Printing columns in a table

# %%
print(raw_data_country_wise2.columns)
# Out:
# Index(['Country/Region', 'Confirmed', 'Deaths', 'Recovered', 'Active',
#        'Recovery Rate', 'Fatality Rate'],
#       dtype='object')

# %% [markdown]
# # Investigating the Null Values

# %%
raw_data_country_wise2.isnull().sum()
# Out:
# Country/Region    0
# Confirmed         0
# Deaths            0
# Recovered         0
# Active            0
# Recovery Rate     0
# Fatality Rate     0
# dtype: int64

# %%
print("The Shape of confirmed is: ", raw_data_country_wise2.shape)
# Out:
# The Shape of confirmed is:  (1496, 7)
